# %% [markdown]
# <a href="https://colab.research.google.com/github/PreethikaDinesh/https-github.com-PreethikaDinesh-Singpore-resale-flat/blob/main/Singpore_resale_flat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv("ResaleFlatPricesBasedonApprovalDate19901999.csv")
df2=pd.read_csv("ResaleFlatPricesBasedonApprovalDate2000Feb2012.csv")
df3=pd.read_csv("ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014.csv")
df4=pd.read_csv("ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv")
df5=pd.read_csv("ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv")

# %%
df = [df1, df2, df3, df4, df5]
df=pd.concat(df, axis=0, ignore_index=True)
df
# Out:
#           month        town         flat_type block       street_name  \
# 0       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 1       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 2       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 3       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 4       1990-01  ANG MO KIO            3 ROOM   216  ANG MO KIO AVE 1
# ...         ...         ...               ...   ...               ...
# 925884  2024-04      YISHUN         EXECUTIVE   826      YISHUN ST 81
# 925885  2024-04      YISHUN         EXECUTIVE   836      YISHUN ST 81
# 925886  2024-05      YISHUN         EXECUTIVE   834      YISHUN ST 81
# 925887  2024-02      YISHUN  MULTI-GENERATION   666      YISHUN AVE 4
# 925888  2024-03      YISHUN  MULTI-GENERATION   666      YISHUN AVE 4
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %% [markdown]
# ##clean the dataset

# %%
# missing values - no missing values
# data right format -
# structured data -
# outliers -
# duplicates -

# %% [markdown]
# ##missing values

# %%
df.isna().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# dtype: int64

# %% [markdown]
# ##duplicates

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (923993, 11)

# %% [markdown]
# ##structure

# %%
df.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# dtype: object

# %%
df.month.values[0]
# Out:
# '1990-01'

# %%
import pandas as pd

# Get the column name dynamically (assuming you know the position, e.g., first column)
date_column = df.columns[0]

# Convert the column to datetime format
df[date_column] = pd.to_datetime(df[date_column], format='%Y-%m')

# Extract month and year into separate columns
df['year'] = df[date_column].dt.year
df['month'] = df[date_column].dt.month
# Out:
# <ipython-input-9-a88be4a4c766>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[date_column] = pd.to_datetime(df[date_column], format='%Y-%m')
# <ipython-input-9-a88be4a4c766>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df[date_column].dt.year
# <ipython-input-9-a88be4a4c766>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df
# Out:
#         month        town         flat_type block       street_name  \
# 0           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 1           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 2           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 3           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 4           1  ANG MO KIO            3 ROOM   216  ANG MO KIO AVE 1
# ...       ...         ...               ...   ...               ...
# 925884      4      YISHUN         EXECUTIVE   826      YISHUN ST 81
# 925885      4      YISHUN         EXECUTIVE   836      YISHUN ST 81
# 925886      5      YISHUN         EXECUTIVE   834      YISHUN ST 81
# 925887      2      YISHUN  MULTI-GENERATION   666      YISHUN AVE 4
# 925888      3      YISHUN  MULTI-GENERATION   666      YISHUN AVE 4
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
df.town.values[0]
# Out:
# 'ANG MO KIO'

# %%
df.flat_type.values[0]
# Out:
# '1 ROOM'

# %%
df.flat_type.unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION', 'MULTI-GENERATION'], dtype=object)

# %%
df.flat_type=df.flat_type.replace("MULTI-GENERATION","MULTI GENERATION")
# Out:
# <ipython-input-14-f5805eca1805>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.flat_type=df.flat_type.replace("MULTI-GENERATION","MULTI GENERATION")

# %%
df.flat_type.unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION'], dtype=object)

# %%
#Removing the alphanumeric characters from the block column
# Converting the block column to int
df['block'] = df['block'].astype(str)
df['block'] = df['block'].apply(lambda x: ''.join(char for char in x if char in '0123456789'))
# Now df['block'] should contain only digits in each element
df['block'] = df['block'].astype(int)
# Out:
# <ipython-input-16-470bf76fa25b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['block'] = df['block'].astype(str)
# <ipython-input-16-470bf76fa25b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['block'] = df['block'].apply(lambda x: ''.join(char for char in x if char in '0123456789'))
# <ipython-input-16-470bf76fa25b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df['remaining_lease'].fillna('0',inplace = True)
# Out:
# <ipython-input-17-3d3ea67d0a06>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['remaining_lease'].fillna('0',inplace = True)

# %% [markdown]
# ##EDA AND ENCODING

# %%
df
# Out:
#         month        town         flat_type  block       street_name  \
# 0           1  ANG MO KIO            1 ROOM    309  ANG MO KIO AVE 1
# 1           1  ANG MO KIO            1 ROOM    309  ANG MO KIO AVE 1
# 2           1  ANG MO KIO            1 ROOM    309  ANG MO KIO AVE 1
# 3           1  ANG MO KIO            1 ROOM    309  ANG MO KIO AVE 1
# 4           1  ANG MO KIO            3 ROOM    216  ANG MO KIO AVE 1
# ...       ...         ...               ...    ...               ...
# 925884      4      YISHUN         EXECUTIVE    826      YISHUN ST 81
# 925885      4      YISHUN         EXECUTIVE    836      YISHUN ST 81
# 925886      5      YISHUN         EXECUTIVE    834      YISHUN ST 81
# 925887      2      YISHUN  MULTI GENERATION    666      YISHUN AVE 4
# 925888      3      YISHUN  MULTI GENERATION    666      YISHUN AVE 4
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
df.groupby('town')['resale_price'].mean().reset_index().plot.line(x = 'town', y= 'resale_price')
# Out:
# <Axes: xlabel='town'>

# %%
df.plot.scatter(x = 'floor_area_sqm', y = 'resale_price')
df[['floor_area_sqm', 'resale_price']].corr()#AFTER ENCODING
# Out:
#                 floor_area_sqm  resale_price
# floor_area_sqm        1.000000      0.562969
# resale_price          0.562969      1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['floor_area_sqm'].plot(kind='hist', bins=20, title='floor_area_sqm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['resale_price'].plot(kind='hist', bins=20, title='resale_price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='floor_area_sqm', y='resale_price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df.plot.scatter(x = 'lease_commence_date', y = 'resale_price')
df[['lease_commence_date', 'resale_price']].corr()#AFTER ENCODING
# Out:
#                      lease_commence_date  resale_price
# lease_commence_date             1.000000      0.537691
# resale_price                    0.537691      1.000000

# %%
df.plot.scatter(x = 'flat_type', y = 'resale_price')
df[['flat_type', 'resale_price']].corr()#AFTER ENCODING
# Out:
#               flat_type  resale_price
# flat_type      1.000000      0.589167
# resale_price   0.589167      1.000000

# %%
df.plot.scatter(x = 'block', y = 'resale_price')
df[['block', 'resale_price']].corr()#AFTER ENCODING
# Out:
#                  block  resale_price
# block         1.000000      0.074499
# resale_price  0.074499      1.000000

# %%
df['lease_commence_date'] =df['lease_commence_date']
plt.figure(figsize=(10, 6))
sns.lineplot(x='year', y='resale_price', data=df)
plt.title('Resale Price Trend Over Time')
plt.xlabel('Year')
plt.ylabel('Resale Price')
plt.show()
# Out:
# <ipython-input-23-b573bb32f50b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lease_commence_date'] =df['lease_commence_date']

# %%
temp = pd.DataFrame(df.groupby('flat_type')['flat_model'].nunique()).reset_index()
print(temp)
plt.figure(figsize = (5,4))
plt.pie(temp['flat_model'], labels = temp['flat_type'], autopct = '%.0f%%')
plt.show()
# Out:
#           flat_type  flat_model
# 0            1 ROOM           2
# 1            2 ROOM           9
# 2            3 ROOM          15
# 3            4 ROOM          18
# 4            5 ROOM          17
# 5         EXECUTIVE           8
# 6  MULTI GENERATION           2

# %% [markdown]
# ##Encoding

# %%
df.drop("remaining_lease",inplace = True , axis = 1)
# Out:
# <ipython-input-25-ce6f6b76d21c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("remaining_lease",inplace = True , axis = 1)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['street_name'] = label_encoder.fit_transform(df['street_name'])
label_encoder = LabelEncoder()
df['flat_type'] = label_encoder.fit_transform(df['flat_type'])
label_encoder = LabelEncoder()
df['flat_model'] = label_encoder.fit_transform(df['flat_model'])
label_encoder = LabelEncoder()
df['town'] = label_encoder.fit_transform(df['town'])
label_encoder = LabelEncoder()
df['storey_range'] = label_encoder.fit_transform(df['storey_range'])
# Out:
# <ipython-input-26-059959ad3f05>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['street_name'] = label_encoder.fit_transform(df['street_name'])
# <ipython-input-26-059959ad3f05>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flat_type'] = label_encoder.fit_transform(df['flat_type'])
# <ipython-input-26-059959ad3f05>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#Correlation
feature_cols = ['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
       'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price', 'year']
plt.figure(figsize = (18,12))
sns.heatmap(df[feature_cols].corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ##Spliting

# %%
df.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price',
#        'year'],
#       dtype='object')

# %%
# Split the data into features and target
x = df[['month','town','flat_type','block','street_name','storey_range','floor_area_sqm','flat_model','lease_commence_date','year']]
y = df['resale_price']

# %%
from sklearn.model_selection import train_test_split

# Split the data into train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=145)

# %% [markdown]
# ##Scaling -Scaling is not mandatory

# %% [markdown]
# ##Model

# %%
# Linear Regression
from sklearn import metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(f'MAE = {metrics.mean_absolute_error(y_test,y_pred)}')
print(f'MSE = {metrics.mean_squared_error(y_test,y_pred)}')
print(f'RMSE  = {np.sqrt(metrics.mean_squared_error(y_test,y_pred))}')
print(f'R2 Score = {model.score(x_test,y_test)}')
# Out:
# MAE = 60522.38127196058
# MSE = 6617858462.214646
# RMSE  = 81350.22103359428
# R2 Score = 0.7727390703656294

# %%
#DecisionTreeRegressor
from sklearn.tree import DecisionTreeRegressor
decision_tree_regressor = DecisionTreeRegressor()
decision_tree_regressor.fit(x_train, y_train)
y_pred = decision_tree_regressor.predict(x_test)
print(f'MAE is - {metrics.mean_absolute_error(y_test, y_pred)}')
print(f'MAE is - {metrics.mean_squared_error(y_test, y_pred)}')
print(f'RMSE is - {np.sqrt(metrics.mean_squared_error(y_test, y_pred))}')
print(f'R2 Score is - {decision_tree_regressor.score(x_test, y_test)}')
# Out:
# MAE is - 19616.37922504714
# MAE is - 897534773.865386
# RMSE is - 29958.884723323496
# R2 Score is - 0.9691781581228374

# %%
#RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
rf_regressor = RandomForestRegressor(n_estimators=50, max_depth=10)
rf_regressor.fit(x_train, y_train)
y_pred = rf_regressor.predict(x_test)
print(f'MAE is - {metrics.mean_absolute_error(y_test, y_pred)}')
print(f'MAE is - {metrics.mean_squared_error(y_test, y_pred)}')
print(f'RMSE is - {np.sqrt(metrics.mean_squared_error(y_test, y_pred))}')
print(f'Accuracy Score is - {rf_regressor.score(x_test, y_test)}')
# Out:
# MAE is - 32747.74851459411
# MAE is - 2299098078.614102
# RMSE is - 47948.91113064093
# Accuracy Score is - 0.9208519396136186

# %%
#XGBoost Regressor
from xgboost import XGBRegressor
xgb = XGBRegressor()
xgb.fit(x_train, y_train)
y_pred = xgb.predict(x_test)
print(f'MAE is - {metrics.mean_absolute_error(y_test, y_pred)}')
print(f'MAE is - {metrics.mean_squared_error(y_test, y_pred)}')
print(f'RMSE is - {np.sqrt(metrics.mean_squared_error(y_test, y_pred))}')
print(f'Accuracy Score is - {rf_regressor.score(x_test, y_test)}')
# Out:
# MAE is - 17330.225521865716
# MAE is - 608922774.0884496
# RMSE is - 24676.360632971177
# Accuracy Score is - 0.921341099121085

# %% [markdown]
# ##saving the model

# %%
import pickle
with open ('dt.pkl', 'wb') as f:
    pickle.dump(decision_tree_regressor , f)

# %% [markdown]
# #Final result

# %% [markdown]
# BY RUNNING ALL THE REGRESSION MODEL WE CONCLUDE THAT **DECISION TREE REGRESSION** HAS HIGH R2 Score is - 0.9691781581228374
# HENCE IT IS THE BEST MODEL
